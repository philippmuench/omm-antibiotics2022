# %%
Loads the .vcf files (Snakemake output) and generates a annotated rds dataset

Requires:
- pipeline_data/vcf_wgs_130721/*.vcf
- datasets/contig_mapping_240621.csv
- datasets/gff3_from_genbank_220621/*.gff3"

# %%
setwd("../../")

# %%
install.packages("vcfR")
# Out:
# also installing the dependencies ‘permute’, ‘cluster’, ‘ape’, ‘memuse’, ‘pinfsc50’, ‘vegan’
#
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
if (!require("BiocManager", quietly = TRUE))
    install.packages("BiocManager")

BiocManager::install("rtracklayer")
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# '?repositories' for details
#
# replacement repositories:
#     CRAN: https://cran.r-project.org
#
#
# Bioconductor version 3.14 (BiocManager 1.30.16), R 4.1.3 (2022-03-10)
#
# Installing package(s) 'BiocVersion', 'rtracklayer'
#
# also installing the dependencies ‘formatR’, ‘lambda.r’, ‘futile.options’, ‘matrixStats’, ‘futile.logger’, ‘snow’, ‘MatrixGenerics’, ‘Biobase’, ‘DelayedArray’, ‘GenomeInfoDbData’, ‘BiocParallel’, ‘Rhtslib’, ‘SummarizedExperiment’, ‘rjson’, ‘GenomicRanges’, ‘XML’, ‘BiocGenerics’, ‘S4Vectors’, ‘IRanges’, ‘XVector’, ‘GenomeInfoDb’, ‘Biostrings’, ‘zlibbioc’, ‘Rsamtools’, ‘GenomicAlignments’, ‘BiocIO’, ‘restfulr’
#
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Old packages: 'blob', 'gert', 'later', 'parallelly', 'randomForest', 'RSQLite'

# %%
#source("utils/helpers.R")
library(rtracklayer)
library(data.table)
library(tidyr)
library(vcfR)

# %%
library(OligoMMR2)

# %% [markdown]
# Parameters

# %%
qual_threshold <- 0 # removes SNPs that have a value below qual_threshold in the QUAL field in the .vcf file
vcf_files <- Sys.glob("pipeline_data/vcf/vcf_wgs_130721/*.vcf") # Path to vcf files
gff_files <- Sys.glob("datasets/gff3_from_genbank_220621/*.gff3") # Path to annotaiton of reference genomes
contig_mapping_path <- "datasets/contig_mapping_240621.csv" # Path to mapping file

# %% [markdown]
# Imports a vcf file and returns the annotated data frame
# vcf_files Path to vcf file
# ontig_mapping Table with mapping of contig to genome ID
# gff_df Dataframe containing the genome annotation e.g. produced by Prokka
# Returns A dataframe containing annotation fields

# %%
vcfToDataframe <- function(vcf_files, contig_mapping = contig_mapping, gff_df = gff_df) {
  res <- list()
  for (vcf.file in vcf_files) {
    message(vcf.file)
    vcf.content <- vcfR::read.vcfR(vcf.file, verbose = FALSE)
    vcf.fix <- as.data.frame(vcf.content@fix) # contains chr, position and substitution informations
    vcf.info <- vcfR::INFO2df(vcf.content) # get INFO field, contains DP, AF informations
    if(nrow(vcf.fix) > 0) { # there are variants
      dat <-  as.data.frame(cbind(vcf.fix[,c(1, 2, 4, 5, 6)], vcf.info[,c(1, 2)]))
      dat$majorAF <- sapply(dat$AF, minorAfToMajorAf)
      dat$genome <- contig_mapping[match(dat$CHROM, contig_mapping$contig),]$genome
      dat$genome_hr <- translateGenomeIdToFullName(tolower(dat$genome))
      dat$mouse.id <-  substr(tools::file_path_sans_ext(basename(vcf.file)), 1, 4)
      dat$mouse.group <- translateMouseIdToTreatmentGroup(dat$mouse.id)
      dat$day <- as.integer(substr(basename(vcf.file), 6, 7))
      dat$phase <- binDaysByPhase(as.numeric(as.matrix(dat$day)))
      dat$phase_num <- binDaysByPhaseGroup(dat$day)
      dat$dp <- as.numeric(as.matrix(vcf.info$DP))
      # annotate overlap with a ORF
      dt.gff <- data.table(start = gff_df$start, end = gff_df$end,
                           chr = as.character(as.matrix(gff_df$chr)), feature = gff_df$product)
      colnames(dat)[1:2] <- c("chr", "start")
      dat$start <- as.integer(as.matrix(dat$start))
      dat$chr <- as.character(as.matrix(dat$chr))
      dat$end <- dat$start
      dat2 <- as.data.table(dat)
      setkey(dt.gff, chr, start, end)
      annotated <- foverlaps(dat2, dt.gff, type = "within", mult = "first")
      res[[tools::file_path_sans_ext(basename(vcf.file))]] <- annotated
    } else{
      message(paste("Skipping", file))
    }
  }
  df <- as.data.frame(do.call(rbind, res)) # merge list to df
  return(df)
}

# %%
gff_df <- NULL
for (gff.file in gff_files) {

  gff <- rtracklayer::readGFF(gff.file)
  relevant <- data.frame(start = gff$start, end = gff$end, type = as.character(as.matrix(gff$type)), gene = as.character(as.matrix(gff$gene)), product = as.character(as.matrix(gff$product)), chr = as.character(as.matrix(gff$seqid)))
  relevant$genome <-  substr(basename(gff.file), 1, nchar(basename(gff.file)) - 5)
  gff_df <- rbind(gff_df, relevant)
  gff_df <- gff_df[which( gff_df$type== "CDS"),]
}

dim(gff_df)
head(gff_df)
# Out:
# [1] 41101     7
#    start end  type gene product
# 3   403   675 CDS  NA   type II toxin-antitoxin system YafQ family toxin
# 5   668   910 CDS  NA   hypothetical protein
# 7  1284  2432 CDS  NA   site-specific integrase
# 9  2562  3911 CDS  NA   hypothetical protein
# 11 3914  4321 CDS  NA   hypothetical protein
# 13 4644  5006 CDS  NA   helix-turn-helix domain-containing protein
#    chr                      genome
# 3  Acutalibacter_muris_KB18 Acutalibacter_muris
# 5  Acutalibacter_muris_KB18 Acutalibacter_muris
# 7  Acutalibacter_muris_KB18 Acutalibacter_muris
# 9  Acutalibacter_muris_KB18 Acutalibacter_muris
# 11 Acutalibacter_muris_KB18 Acutalibacter_muris
# 13 Acutalibacter_muris_KB18 Acutalibacter_muris

# %%
contig_mapping <- read.csv2(contig_mapping_path, sep = ";",
                            header = T, stringsAsFactors = F)
head(contig_mapping)
# Out:
#   contig                       genome
# 1 Akkermansia_muciniphila_YL44 YL44
# 2 Acutalibacter_muris_KB18     KB18
# 3 Bifidobacterium_animalis_YL2 YL2
# 4 Bacteroides_caecimuris_I48   I48
# 5 Blautia_coccoides_YL58       YL58
# 6 Clostridium_innocuum_I46     I46

# %%
minorAfToMajorAf <- function(x) if (x > 0) max(1 - x, x) else NA

# %%
vcf_samples <- vcfToDataframe(vcf_files, contig_mapping, gff_df = gff_df)
vcf_samples$feature <- as.character(as.matrix(vcf_samples$feature))
vcf_samples[which(is.na(vcf_samples$feature)),]$feature <- "outside ORFs"
vcf_samples$start <- NULL
vcf_samples$end <- NULL
vcf_samples$i.end <- NULL
colnames(vcf_samples)[3] <- "POS"
vcf_samples$ref_size <- nchar(as.character(as.matrix(vcf_samples$REF)))
vcf_samples$alt_size <- nchar(as.character(as.matrix(vcf_samples$ALT)))
vcf_samples$alteration <- paste(as.character(vcf_samples$REF), "->",as.character(vcf_samples$ALT))
vcf_samples$alteration_type <- "SNP"
vcf_samples$QUAL <- as.integer(as.matrix(vcf_samples$QUAL))
vcf_samples <- vcf_samples[which(vcf_samples$QUAL >= qual_threshold),]
vcf_samples$snp_id <- paste0(vcf_samples$POS, "-", vcf_samples$REF, "-", vcf_samples$ALT)
head(vcf_samples)
# Out:
# pipeline_data/vcf/vcf_wgs_130721/1681d00_S56.vcf
#
# Loading required package: dplyr
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:GenomicRanges’:
#
#     intersect, setdiff, union
#
#
# The following object is masked from ‘package:GenomeInfoDb’:
#
#     intersect
#
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# pipeline_data/vcf/vcf_wgs_130721/1681d14_S57.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1681d30_S58.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1681d49_S59.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1681d63_S60.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1681d79_S61.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1683d00_S47.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1683d04_S48.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1683d09_S49.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1683d14_S50.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1683d18_S51.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1683d23_S52.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1683d30_S53.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1683d37_S54.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1683d44_S55.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1683d49_S56.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1683d53_S57.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1683d58_S58.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1683d63_S59.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1683d67_S60.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1683d72_S61.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1683d79_S62.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1684d00_S62.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1684d14_S63.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1684d30_S64.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1684d49_S65.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1684d63_S66.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1684d79_S67.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1686d00_S69.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1686d14_S70.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1686d30_S71.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1686d49_S72.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1686d63_S73.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1686d79_S74.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1688d00_S1.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1688d04_S2.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1688d09_S3.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1688d14_S4.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1688d18_S5.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1688d23_S6.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1688d30_S7.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1688d37_S8.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1688d44_S9.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1688d49_S10.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1688d53_S11.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1688d58_S12.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1688d63_S13.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1688d67_S14.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1688d72_S15.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1688d79_S16.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1690d00_S75.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1690d14_S76.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1690d30_S77.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1690d49_S78.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1690d63_S79.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1690d79_S80.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1692d00_S17.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1692d04_S18.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1692d09_S19.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1692d14_S20.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1692d18_S21.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1692d23_S22.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1692d30_S23.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1692d37_S24.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1692d44_S25.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1692d49_S26.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1692d53_S27.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1692d58_S28.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1692d63_S29.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1692d67_S30.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1692d72_S31.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1692d79_S32.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1693d00_S81.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1693d14_S82.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1693d30_S83.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1693d49_S84.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1693d63_S85.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1693d79_S86.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1694d00_S87.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1694d14_S88.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1694d30_S89.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1694d49_S90.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1694d63_S91.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1694d79_S43.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1697d00_S50.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1697d14_S51.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1697d30_S52.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1697d49_S53.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1697d63_S54.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1697d79_S55.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1698d00_S44.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1698d14_S45.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1698d30_S46.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1698d49_S47.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1698d63_S48.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1698d79_S49.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1699d00_S33.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1699d04_S34.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1699d09_S35.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1699d14_S36.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1699d18_S37.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1699d23_S38.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1699d30_S39.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1699d37_S40.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1699d44_S41.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1699d49_S42.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1699d53_S63.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1699d58_S64.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1699d63_S65.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1699d67_S66.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1699d72_S67.vcf
#
# pipeline_data/vcf/vcf_wgs_130721/1699d79_S68.vcf
#   chr
# 1 Akkermansia_muciniphila_YL44
# 2 Akkermansia_muciniphila_YL44
# 3 Akkermansia_muciniphila_YL44
# 4 Akkermansia_muciniphila_YL44
# 5 Akkermansia_muciniphila_YL44
# 6 Akkermansia_muciniphila_YL44
#   feature                                                          POS    REF
# 1 autotransporter-associated beta strand repeat-containing protein 239850 C
# 2 autotransporter-associated beta strand repeat-containing protein 240383 A
# 3 autotransporter-associated beta strand repeat-containing protein 241793 A
# 4 PEP-CTERM sorting domain-containing protein                      296139 C
# 5 protein kinase                                                   355082 A
# 6 protein kinase                                                   355082 A
#   ALT QUAL DP  AF       majorAF  genome ⋯ mouse.group day phase
# 1 T   1402 129 0.379845 0.620155 YL44   ⋯ Control     0   pre-treatment
# 2 G   1086 116 0.344828 0.655172 YL44   ⋯ Control     0   pre-treatment
# 3 G    116 129 0.046512 0.953488 YL44   ⋯ Control     0   pre-treatment
# 4 T   1067 160 0.250000 0.750000 YL44   ⋯ Control     0   pre-treatment
# 5 G   1281 130 0.353846 0.646154 YL44   ⋯ Control     0   pre-treatment
# 6 T    950 130 0.276923 0.723077 YL44   ⋯ Control     0   pre-treatment
#   phase_num dp  ref_size alt_size alteration alteration_type snp_id
# 1 1         129 1        1        C -> T     SNP             239850-C-T
# 2 1         116 1        1        A -> G     SNP             240383-A-G
# 3 1         129 1        1        A -> G     SNP             241793-A-G
# 4 1         160 1        1        C -> T     SNP             296139-C-T
# 5 1         130 1        1        A -> G     SNP             355082-A-G
# 6 1         130 1        1        A -> T     SNP             355082-A-T

# %%
saveRDS(vcf_samples, file = "R/datasets/omm_wgs_rerun.rds")
